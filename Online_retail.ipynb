# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

import re

import xlrd

# %%
df = pd.read_excel('Online Retail.xlsx')
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %%
def df_describer(df):
    '''
    Функция для описания таблицы. Выдает:
    - общую информацию о таблице;
    - количество пропусков;
    - количество дубликатов;
    - описание данных.
    Принимает в качестве аргумента переменную с датафреймом.
    '''
    print('Общая информация о таблице: ')
    print(df.info())
    print('=============')
    print('Пропуски в данных: ')
    display(
        df.isna().mean().to_frame('Nan')
        .join(df.isna().mean().to_frame('Nan, %'))
        .style.format({'Nan, %': '{:,.1%}'.format})
    )
    print('=============')
    print('Количество дублей: ')
    print(df.duplicated().sum())
    print('=============')
    print('Описание данных')
    display(df.describe(include='all'))

# %%
df_describer(df)
# Out:
# Общая информация о таблице:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  datetime64[ns]
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 33.1+ MB
# None
# =============
# Пропуски в данных:
# <style  type="text/css" >
# </style><table id="T_409f6_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Nan</th>        <th class="col_heading level0 col1" >Nan, %</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_409f6_level0_row0" class="row_heading level0 row0" >InvoiceNo</th>
#                         <td id="T_409f6_row0_col0" class="data row0 col0" >0.000000</td>
#                         <td id="T_409f6_row0_col1" class="data row0 col1" >0.0%</td>
#             </tr>
#             <tr>
#                         <th id="T_409f6_level0_row1" class="row_heading level0 row1" >StockCode</th>
#                         <td id="T_409f6_row1_col0" class="data row1 col0" >0.000000</td>
#                         <td id="T_409f6_row1_col1" class="data row1 col1" >0.0%</td>
#             </tr>
#             <tr>
#                         <th id="T_409f6_level0_row2" class="row_heading level0 row2" >Description</th>
#                         <td id="T_409f6_row2_col0" class="data row2 col0" >0.002683</td>
#                         <td id="T_409f6_row2_col1" class="data row2 col1" >0.3%</td>
#             </tr>
#             <tr>
#                         <th id="T_409f6_level0_row3" class="row_heading level0 row3" >Quantity</th>
#                         <td id="T_409f6_row3_col0" class="data row3 col0" >0.000000</td>
#                         <td id="T_409f6_row3_col1" class="data row3 col1" >0.0%</td>
#             </tr>
#             <tr>
#                         <th id="T_409f6_level0_row4" class="row_heading level0 row4" >InvoiceDate</th>
#                         <td id="T_409f6_row4_col0" class="data row4 col0" >0.000000</td>
#                         <td id="T_409f6_row4_col1" class="data row4 col1" >0.0%</td>
#             </tr>
#             <tr>
#                         <th id="T_409f6_level0_row5" class="row_heading level0 row5" >UnitPrice</th>
#                         <td id="T_409f6_row5_col0" class="data row5 col0" >0.000000</td>
#                         <td id="T_409f6_row5_col1" class="data row5 col1" >0.0%</td>
#             </tr>
#             <tr>
#                         <th id="T_409f6_level0_row6" class="row_heading level0 row6" >CustomerID</th>
#                         <td id="T_409f6_row6_col0" class="data row6 col0" >0.249267</td>
#                         <td id="T_409f6_row6_col1" class="data row6 col1" >24.9%</td>
#             </tr>
#             <tr>
#                         <th id="T_409f6_level0_row7" class="row_heading level0 row7" >Country</th>
#                         <td id="T_409f6_row7_col0" class="data row7 col0" >0.000000</td>
#                         <td id="T_409f6_row7_col1" class="data row7 col1" >0.0%</td>
#             </tr>
#     </tbody></table>
# =============
# Количество дублей:
# 5268
# =============
# Описание данных
# <ipython-input-3-ebc6a831f7d4>:24: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   display(df.describe(include='all'))
#         InvoiceNo StockCode                         Description  \
# count    541909.0    541909                              540455
# unique    25900.0      4070                                4223
# top      573585.0    85123A  WHITE HANGING HEART T-LIGHT HOLDER
# freq       1114.0      2313                                2369
# first         NaN       NaN                                 NaN
# last          NaN       NaN                                 NaN
# mean          NaN       NaN                                 NaN
# std           NaN       NaN                                 NaN
# min           NaN       NaN                                 NaN
# 25%           NaN       NaN                                 NaN
# 50%           NaN       NaN                                 NaN
# 75%           NaN       NaN                                 NaN
# max           NaN       NaN                                 NaN
#
#              Quantity          InvoiceDate      UnitPrice     CustomerID  \
# count   541909.000000               541909  541909.000000  406829.000000
# unique            NaN                23260            NaN            NaN
# top               NaN  2011-10-31 14:41:00            NaN            NaN
# freq              NaN                 1114            NaN            NaN
# first             NaN  2010-12-01 08:26:00            NaN            NaN
# last              NaN  2011-12-09 12:50:00            NaN            NaN
# mean         9.552250                  NaN       4.611114   15287.690570
# std        218.081158                  NaN      96.759853    1713.600303
# min     -80995.000000                  NaN  -11062.060000   12346.000000
# 25%          1.000000                  NaN       1.250000   13953.000000
# 50%          3.000000                  NaN       2.080000   15152.000000
# 75%         10.000000                  NaN       4.130000   16791.000000
# max      80995.000000                  NaN   38970.000000   18287.000000
#
#                Country
# count           541909
# unique              38
# top     United Kingdom
# freq            495478
# first              NaN
# last               NaN
# mean               NaN
# std                NaN
# min                NaN
# 25%                NaN
# 50%                NaN
# 75%                NaN
# max                NaN

# %% [markdown]
# Что поищем:
# 1) Исследуем и уберем дубли
# 2) посмотрим, что за клиенты без ID - что с ними делать, их много, столько удалять нельзя
# 3) Что за товары без описания и что с ними делать (их немного, можно удалить, если что)
# 4) переведем InvoiceDate в datetime, сделаем новый столбец с датой без времени, сделаем столбец с месяцем
# - кластеризация товаров
# 5) исследуем цены:
#     5.1) Построим гистограмму
#     5.2) Выявим что за товары с отрицательной стоимостью (поймем, что с ними делать)
#     5.3) товары с отрицательным количеством тоже интересно
#     5.4) Построим топ 10 с самыми дорогими товарами, с самыми покупаемыми товарами
#     5.5) создадим столбец с total_price = Quantity*UnitPrice
# 6) исследуем покупателей:
#     6.1) соберем таблицу с агрегацией по инвойсу, дате, месяц, страной, id-покупателя, кол-во позицией в инвойсе, кол-вом товаров, суммой
#     6.1) Топ 10 стран по обороту
#     6.2) Топ 10 стран по среднему чеку - ? подумать, как посчитать
#
# Еще надо оценить доли, занимаемые странами
#
# Построить график выручки по месяцам

# %% [markdown]
# так как дублей у нас менее 1%, удаляем их:

# %%
df = df.drop_duplicates()
df_describer(df)
# Out:
# Общая информация о таблице:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 536641 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    536641 non-null  object
#  1   StockCode    536641 non-null  object
#  2   Description  535187 non-null  object
#  3   Quantity     536641 non-null  int64
#  4   InvoiceDate  536641 non-null  datetime64[ns]
#  5   UnitPrice    536641 non-null  float64
#  6   CustomerID   401604 non-null  float64
#  7   Country      536641 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 36.8+ MB
# None
# =============
# Пропуски в данных:
# <style  type="text/css" >
# </style><table id="T_235e4_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Nan</th>        <th class="col_heading level0 col1" >Nan, %</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_235e4_level0_row0" class="row_heading level0 row0" >InvoiceNo</th>
#                         <td id="T_235e4_row0_col0" class="data row0 col0" >0.000000</td>
#                         <td id="T_235e4_row0_col1" class="data row0 col1" >0.0%</td>
#             </tr>
#             <tr>
#                         <th id="T_235e4_level0_row1" class="row_heading level0 row1" >StockCode</th>
#                         <td id="T_235e4_row1_col0" class="data row1 col0" >0.000000</td>
#                         <td id="T_235e4_row1_col1" class="data row1 col1" >0.0%</td>
#             </tr>
#             <tr>
#                         <th id="T_235e4_level0_row2" class="row_heading level0 row2" >Description</th>
#                         <td id="T_235e4_row2_col0" class="data row2 col0" >0.002709</td>
#                         <td id="T_235e4_row2_col1" class="data row2 col1" >0.3%</td>
#             </tr>
#             <tr>
#                         <th id="T_235e4_level0_row3" class="row_heading level0 row3" >Quantity</th>
#                         <td id="T_235e4_row3_col0" class="data row3 col0" >0.000000</td>
#                         <td id="T_235e4_row3_col1" class="data row3 col1" >0.0%</td>
#             </tr>
#             <tr>
#                         <th id="T_235e4_level0_row4" class="row_heading level0 row4" >InvoiceDate</th>
#                         <td id="T_235e4_row4_col0" class="data row4 col0" >0.000000</td>
#                         <td id="T_235e4_row4_col1" class="data row4 col1" >0.0%</td>
#             </tr>
#             <tr>
#                         <th id="T_235e4_level0_row5" class="row_heading level0 row5" >UnitPrice</th>
#                         <td id="T_235e4_row5_col0" class="data row5 col0" >0.000000</td>
#                         <td id="T_235e4_row5_col1" class="data row5 col1" >0.0%</td>
#             </tr>
#             <tr>
#                         <th id="T_235e4_level0_row6" class="row_heading level0 row6" >CustomerID</th>
#                         <td id="T_235e4_row6_col0" class="data row6 col0" >0.251634</td>
#                         <td id="T_235e4_row6_col1" class="data row6 col1" >25.2%</td>
#             </tr>
#             <tr>
#                         <th id="T_235e4_level0_row7" class="row_heading level0 row7" >Country</th>
#                         <td id="T_235e4_row7_col0" class="data row7 col0" >0.000000</td>
#                         <td id="T_235e4_row7_col1" class="data row7 col1" >0.0%</td>
#             </tr>
#     </tbody></table>
# =============
# Количество дублей:
# 0
# =============
# Описание данных
# <ipython-input-3-ebc6a831f7d4>:24: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   display(df.describe(include='all'))
#         InvoiceNo StockCode                         Description  \
# count    536641.0    536641                              535187
# unique    25900.0      4070                                4223
# top      573585.0    85123A  WHITE HANGING HEART T-LIGHT HOLDER
# freq       1114.0      2301                                2357
# first         NaN       NaN                                 NaN
# last          NaN       NaN                                 NaN
# mean          NaN       NaN                                 NaN
# std           NaN       NaN                                 NaN
# min           NaN       NaN                                 NaN
# 25%           NaN       NaN                                 NaN
# 50%           NaN       NaN                                 NaN
# 75%           NaN       NaN                                 NaN
# max           NaN       NaN                                 NaN
#
#              Quantity          InvoiceDate      UnitPrice     CustomerID  \
# count   536641.000000               536641  536641.000000  401604.000000
# unique            NaN                23260            NaN            NaN
# top               NaN  2011-10-31 14:41:00            NaN            NaN
# freq              NaN                 1114            NaN            NaN
# first             NaN  2010-12-01 08:26:00            NaN            NaN
# last              NaN  2011-12-09 12:50:00            NaN            NaN
# mean         9.620029                  NaN       4.632656   15281.160818
# std        219.130156                  NaN      97.233118    1714.006089
# min     -80995.000000                  NaN  -11062.060000   12346.000000
# 25%          1.000000                  NaN       1.250000   13939.000000
# 50%          3.000000                  NaN       2.080000   15145.000000
# 75%         10.000000                  NaN       4.130000   16784.000000
# max      80995.000000                  NaN   38970.000000   18287.000000
#
#                Country
# count           536641
# unique              38
# top     United Kingdom
# freq            490300
# first              NaN
# last               NaN
# mean               NaN
# std                NaN
# min                NaN
# 25%                NaN
# 50%                NaN
# 75%                NaN
# max                NaN

# %% [markdown]
# Переведем столбец с датой и временем в дискретный вид

# %%
df['invoce_day'] = df['InvoiceDate'].dt.date
df.info()
# Out:
# <ipython-input-6-1a2fdc779699>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['invoce_day'] = df['InvoiceDate'].dt.date
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 536641 entries, 0 to 541908
# Data columns (total 9 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    536641 non-null  object
#  1   StockCode    536641 non-null  object
#  2   Description  535187 non-null  object
#  3   Quantity     536641 non-null  int64
#  4   InvoiceDate  536641 non-null  datetime64[ns]
#  5   UnitPrice    536641 non-null  float64
#  6   CustomerID   401604 non-null  float64
#  7   Country      536641 non-null  object
#  8   invoce_day   536641 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(5)
# memory usage: 40.9+ MB

# %%
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country  invoce_day
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom  2010-12-01
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom  2010-12-01
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom  2010-12-01
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom  2010-12-01
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom  2010-12-01

# %% [markdown]
# Добавим столбец с общей стоимостью товара в инвойсе:

# %%
df['total_amt'] = df['Quantity']*df['UnitPrice']
df.sample(10)
# Out:
# <ipython-input-8-5750ef5c26c4>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['total_amt'] = df['Quantity']*df['UnitPrice']
#        InvoiceNo StockCode                     Description  Quantity  \
# 441612    574590     23318  BOX OF 6 MINI VINTAGE CRACKERS         6
# 117677    546397    47590A     BLUE HAPPY BIRTHDAY BUNTING         3
# 425408   C573321     23014  GLASS APOTHECARY BOTTLE ELIXIR        -1
# 193745    553542     48185              DOORMAT FAIRY CAKE         2
# 374946    569414     21481      FAWN BLUE HOT WATER BOTTLE         3
# 496556    578344     16238       PARTY TIME PENCIL ERASERS         1
# 347534    567307     20712      JUMBO BAG WOODLAND ANIMALS        10
# 170622    551339     21929  JUMBO BAG PINK VINTAGE PAISLEY         2
# 347393    567303     23234   BISCUIT TIN VINTAGE CHRISTMAS        12
# 156764    550164     20727         LUNCH BAG  BLACK SKULL.        10
#
#                InvoiceDate  UnitPrice  CustomerID         Country  invoce_day  \
# 441612 2011-11-06 10:44:00       2.49     18077.0  United Kingdom  2011-11-06
# 117677 2011-03-11 14:37:00       5.45     12971.0  United Kingdom  2011-03-11
# 425408 2011-10-30 10:35:00       3.95     14546.0  United Kingdom  2011-10-30
# 193745 2011-05-17 15:34:00      14.13         NaN  United Kingdom  2011-05-17
# 374946 2011-10-04 10:11:00       8.29         NaN  United Kingdom  2011-10-04
# 496556 2011-11-24 09:21:00       0.42         NaN  United Kingdom  2011-11-24
# 347534 2011-09-19 13:35:00       2.08     15078.0  United Kingdom  2011-09-19
# 170622 2011-04-27 17:18:00       4.13         NaN  United Kingdom  2011-04-27
# 347393 2011-09-19 13:20:00       2.89     17613.0  United Kingdom  2011-09-19
# 156764 2011-04-14 16:31:00       1.65     13590.0  United Kingdom  2011-04-14
#
#         total_amt
# 441612      14.94
# 117677      16.35
# 425408      -3.95
# 193745      28.26
# 374946      24.87
# 496556       0.42
# 347534      20.80
# 170622       8.26
# 347393      34.68
# 156764      16.50

# %% [markdown]
# Теперь посмотрим, что делать с клиентами без ID

# %%
df_describer(df[df['CustomerID'].isna()])
# Out:
# Общая информация о таблице:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 135037 entries, 622 to 541540
# Data columns (total 10 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    135037 non-null  object
#  1   StockCode    135037 non-null  object
#  2   Description  133583 non-null  object
#  3   Quantity     135037 non-null  int64
#  4   InvoiceDate  135037 non-null  datetime64[ns]
#  5   UnitPrice    135037 non-null  float64
#  6   CustomerID   0 non-null       float64
#  7   Country      135037 non-null  object
#  8   invoce_day   135037 non-null  object
#  9   total_amt    135037 non-null  float64
# dtypes: datetime64[ns](1), float64(3), int64(1), object(5)
# memory usage: 11.3+ MB
# None
# =============
# Пропуски в данных:
# <style  type="text/css" >
# </style><table id="T_c7c08_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Nan</th>        <th class="col_heading level0 col1" >Nan, %</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_c7c08_level0_row0" class="row_heading level0 row0" >InvoiceNo</th>
#                         <td id="T_c7c08_row0_col0" class="data row0 col0" >0.000000</td>
#                         <td id="T_c7c08_row0_col1" class="data row0 col1" >0.0%</td>
#             </tr>
#             <tr>
#                         <th id="T_c7c08_level0_row1" class="row_heading level0 row1" >StockCode</th>
#                         <td id="T_c7c08_row1_col0" class="data row1 col0" >0.000000</td>
#                         <td id="T_c7c08_row1_col1" class="data row1 col1" >0.0%</td>
#             </tr>
#             <tr>
#                         <th id="T_c7c08_level0_row2" class="row_heading level0 row2" >Description</th>
#                         <td id="T_c7c08_row2_col0" class="data row2 col0" >0.010767</td>
#                         <td id="T_c7c08_row2_col1" class="data row2 col1" >1.1%</td>
#             </tr>
#             <tr>
#                         <th id="T_c7c08_level0_row3" class="row_heading level0 row3" >Quantity</th>
#                         <td id="T_c7c08_row3_col0" class="data row3 col0" >0.000000</td>
#                         <td id="T_c7c08_row3_col1" class="data row3 col1" >0.0%</td>
#             </tr>
#             <tr>
#                         <th id="T_c7c08_level0_row4" class="row_heading level0 row4" >InvoiceDate</th>
#                         <td id="T_c7c08_row4_col0" class="data row4 col0" >0.000000</td>
#                         <td id="T_c7c08_row4_col1" class="data row4 col1" >0.0%</td>
#             </tr>
#             <tr>
#                         <th id="T_c7c08_level0_row5" class="row_heading level0 row5" >UnitPrice</th>
#                         <td id="T_c7c08_row5_col0" class="data row5 col0" >0.000000</td>
#                         <td id="T_c7c08_row5_col1" class="data row5 col1" >0.0%</td>
#             </tr>
#             <tr>
#                         <th id="T_c7c08_level0_row6" class="row_heading level0 row6" >CustomerID</th>
#                         <td id="T_c7c08_row6_col0" class="data row6 col0" >1.000000</td>
#                         <td id="T_c7c08_row6_col1" class="data row6 col1" >100.0%</td>
#             </tr>
#             <tr>
#                         <th id="T_c7c08_level0_row7" class="row_heading level0 row7" >Country</th>
#                         <td id="T_c7c08_row7_col0" class="data row7 col0" >0.000000</td>
#                         <td id="T_c7c08_row7_col1" class="data row7 col1" >0.0%</td>
#             </tr>
#             <tr>
#                         <th id="T_c7c08_level0_row8" class="row_heading level0 row8" >invoce_day</th>
#                         <td id="T_c7c08_row8_col0" class="data row8 col0" >0.000000</td>
#                         <td id="T_c7c08_row8_col1" class="data row8 col1" >0.0%</td>
#             </tr>
#             <tr>
#                         <th id="T_c7c08_level0_row9" class="row_heading level0 row9" >total_amt</th>
#                         <td id="T_c7c08_row9_col0" class="data row9 col0" >0.000000</td>
#                         <td id="T_c7c08_row9_col1" class="data row9 col1" >0.0%</td>
#             </tr>
#     </tbody></table>
# =============
# Количество дублей:
# 0
# =============
# Описание данных
# <ipython-input-3-ebc6a831f7d4>:24: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   display(df.describe(include='all'))
#         InvoiceNo StockCode     Description       Quantity  \
# count    135037.0    135037          133583  135037.000000
# unique     3710.0      3810            3554            NaN
# top      573585.0       DOT  DOTCOM POSTAGE            NaN
# freq       1114.0       694             693            NaN
# first         NaN       NaN             NaN            NaN
# last          NaN       NaN             NaN            NaN
# mean          NaN       NaN             NaN       1.996868
# std           NaN       NaN             NaN      66.705155
# min           NaN       NaN             NaN   -9600.000000
# 25%           NaN       NaN             NaN       1.000000
# 50%           NaN       NaN             NaN       1.000000
# 75%           NaN       NaN             NaN       3.000000
# max           NaN       NaN             NaN    5568.000000
#
#                 InvoiceDate      UnitPrice  CustomerID         Country  \
# count                135037  135037.000000         0.0          135037
# unique                 3161            NaN         NaN               9
# top     2011-10-31 14:41:00            NaN         NaN  United Kingdom
# freq                   1114            NaN         NaN          133572
# first   2010-12-01 11:52:00            NaN         NaN             NaN
# last    2011-12-09 10:26:00            NaN         NaN             NaN
# mean                    NaN       8.078342         NaN             NaN
# std                     NaN     151.924958         NaN             NaN
# min                     NaN  -11062.060000         NaN             NaN
# 25%                     NaN       1.630000         NaN             NaN
# 50%                     NaN       3.290000         NaN             NaN
# 75%                     NaN       5.490000         NaN             NaN
# max                     NaN   17836.460000         NaN             NaN
#
#         invoce_day      total_amt
# count       135037  135037.000000
# unique         277            NaN
# top     2011-08-30            NaN
# freq          2829            NaN
# first          NaN            NaN
# last           NaN            NaN
# mean           NaN      10.719192
# std            NaN     157.992412
# min            NaN  -17836.460000
# 25%            NaN       2.460000
# 50%            NaN       4.960000
# 75%            NaN      10.790000
# max            NaN   13541.330000

# %% [markdown]
# Кажется, инвойс 573585 самый крупный как в общей таблице, так и среди клиентов без ID. Посмотрим, что с ним, возможно, не так:

# %%
df[(df['CustomerID'].isna())&(df['InvoiceNo']==573585)]
# Out:
#        InvoiceNo     StockCode                         Description  Quantity  \
# 430237    573585         11001         ASSTD DESIGN RACING CAR PEN         2
# 430238    573585         15036           ASSORTED COLOURS SILK FAN        15
# 430239    573585         15039                      SANDALWOOD FAN        15
# 430240    573585       15056BL             EDWARDIAN PARASOL BLACK         1
# 430241    573585        15056N           EDWARDIAN PARASOL NATURAL         1
# ...          ...           ...                                 ...       ...
# 431346    573585        90209C         PINK ENAMEL+GLASS HAIR COMB         3
# 431347    573585        90214S           LETTER "S" BLING KEY RING         1
# 431348    573585           DOT                      DOTCOM POSTAGE         1
# 431349    573585  gift_0001_20  Dotcomgiftshop Gift Voucher £20.00         1
# 431350    573585         23539             WALL ART LOVES' SECRET          2
#
#                InvoiceDate  UnitPrice  CustomerID         Country  invoce_day  \
# 430237 2011-10-31 14:41:00       3.29         NaN  United Kingdom  2011-10-31
# 430238 2011-10-31 14:41:00       1.63         NaN  United Kingdom  2011-10-31
# 430239 2011-10-31 14:41:00       1.63         NaN  United Kingdom  2011-10-31
# 430240 2011-10-31 14:41:00      12.46         NaN  United Kingdom  2011-10-31
# 430241 2011-10-31 14:41:00      12.46         NaN  United Kingdom  2011-10-31
# ...                    ...        ...         ...             ...         ...
# 431346 2011-10-31 14:41:00       2.07         NaN  United Kingdom  2011-10-31
# 431347 2011-10-31 14:41:00       0.83         NaN  United Kingdom  2011-10-31
# 431348 2011-10-31 14:41:00    2019.05         NaN  United Kingdom  2011-10-31
# 431349 2011-10-31 14:41:00      16.67         NaN  United Kingdom  2011-10-31
# 431350 2011-10-31 14:41:00       5.79         NaN  United Kingdom  2011-10-31
#
#         total_amt
# 430237       6.58
# 430238      24.45
# 430239      24.45
# 430240      12.46
# 430241      12.46
# ...           ...
# 431346       6.21
# 431347       0.83
# 431348    2019.05
# 431349      16.67
# 431350      11.58
#
# [1114 rows x 10 columns]

# %%
df[(df['CustomerID'].isna())&(df['InvoiceNo'].str.contains('[a-zA-Z]', regex=True))]
# Out:
#        InvoiceNo  StockCode                         Description  Quantity  \
# 11502    C537251      22429          ENAMEL MEASURING JUG CREAM        -2
# 11503    C537251      22620         4 TRADITIONAL SPINNING TOPS        -8
# 11504    C537251      21890   S/6 WOODEN SKITTLES IN COTTON BAG        -2
# 11505    C537251      22564              ALPHABET STENCIL CRAFT        -5
# 11506    C537251      21891    TRADITIONAL WOODEN SKIPPING ROPE        -3
# ...          ...        ...                                 ...       ...
# 492207   C578097      22112          CHOCOLATE HOT WATER BOTTLE       -48
# 514984   C579757      47469  ASSORTED SHAPES PHOTO CLIP SILVER        -24
# 516454   C579907      22169    FAMILY ALBUM WHITE PICTURE FRAME        -2
# 524601   C580604  AMAZONFEE                          AMAZON FEE        -1
# 524602   C580605  AMAZONFEE                          AMAZON FEE        -1
#
#                InvoiceDate  UnitPrice  CustomerID         Country  invoce_day  \
# 11502  2010-12-06 10:45:00       4.25         NaN  United Kingdom  2010-12-06
# 11503  2010-12-06 10:45:00       1.25         NaN  United Kingdom  2010-12-06
# 11504  2010-12-06 10:45:00       2.95         NaN  United Kingdom  2010-12-06
# 11505  2010-12-06 10:45:00       1.25         NaN  United Kingdom  2010-12-06
# 11506  2010-12-06 10:45:00       1.25         NaN  United Kingdom  2010-12-06
# ...                    ...        ...         ...             ...         ...
# 492207 2011-11-22 17:31:00       4.25         NaN  United Kingdom  2011-11-22
# 514984 2011-11-30 14:56:00       0.65         NaN  United Kingdom  2011-11-30
# 516454 2011-12-01 08:48:00       7.65         NaN            EIRE  2011-12-01
# 524601 2011-12-05 11:35:00   11586.50         NaN  United Kingdom  2011-12-05
# 524602 2011-12-05 11:36:00   17836.46         NaN  United Kingdom  2011-12-05
#
#         total_amt
# 11502       -8.50
# 11503      -10.00
# 11504       -5.90
# 11505       -6.25
# 11506       -3.75
# ...           ...
# 492207    -204.00
# 514984     -15.60
# 516454     -15.30
# 524601  -11586.50
# 524602  -17836.46
#
# [382 rows x 10 columns]

# %%
df[(df['CustomerID'].isna())&(df['InvoiceNo'].str.contains('[a-zA-Z]', regex=True))].describe(include='all')
# Out:
# <ipython-input-12-8f0fd4781de8>:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   df[(df['CustomerID'].isna())&(df['InvoiceNo'].str.contains('[a-zA-Z]', regex=True))].describe(include='all')
#        InvoiceNo StockCode Description    Quantity          InvoiceDate  \
# count        382       382         382  382.000000                  382
# unique       185       162         162         NaN                  185
# top      C557663         M      Manual         NaN  2011-06-21 17:59:00
# freq          37        69          69         NaN                   37
# first        NaN       NaN         NaN         NaN  2010-12-06 10:45:00
# last         NaN       NaN         NaN         NaN  2011-12-05 11:36:00
# mean         NaN       NaN         NaN   -6.602094                  NaN
# std          NaN       NaN         NaN   15.293928                  NaN
# min          NaN       NaN         NaN -144.000000                  NaN
# 25%          NaN       NaN         NaN   -5.750000                  NaN
# 50%          NaN       NaN         NaN   -1.000000                  NaN
# 75%          NaN       NaN         NaN   -1.000000                  NaN
# max          NaN       NaN         NaN    1.000000                  NaN
#
#            UnitPrice  CustomerID         Country  invoce_day     total_amt
# count     382.000000         0.0             382         382    382.000000
# unique           NaN         NaN               4          83           NaN
# top              NaN         NaN  United Kingdom  2011-06-21           NaN
# freq             NaN         NaN             323          39           NaN
# first            NaN         NaN             NaN         NaN           NaN
# last             NaN         NaN             NaN         NaN           NaN
# mean      708.341675         NaN             NaN         NaN   -775.791414
# std      2593.435141         NaN             NaN         NaN   2574.202702
# min    -11062.060000         NaN             NaN         NaN -17836.460000
# 25%         2.100000         NaN             NaN         NaN   -205.305000
# 50%        12.845000         NaN             NaN         NaN    -27.315000
# 75%       188.632500         NaN             NaN         NaN    -10.000000
# max     17836.460000         NaN             NaN         NaN  11062.060000

# %% [markdown]
# Все эти инвойсы с отрицательной стоимостью. В описании перечислены как некоторые товары,  так и какие-то штрафы (от Амазона). Уникальных описаний не так много, можно оценить, что там фигурирует.

# %%
(
    df[(df['CustomerID'].isna())&(df['InvoiceNo'].str.contains('[a-zA-Z]', regex=True))]['Description']
    .value_counts().to_frame()
).head(15)
# Out:
#                                    Description
# Manual                                      69
# SAMPLES                                     60
# AMAZON FEE                                  32
# POSTAGE                                     29
# Bank Charges                                25
# Adjust bad debt                              3
# PACK OF 72 RETROSPOT CAKE CASES              3
# 20 DOLLY PEGS RETROSPOT                      2
# BINGO SET                                    2
# ASSORTED COLOUR BIRD ORNAMENT                2
# CHRISTMAS METAL TAGS ASSORTED                2
# MAGNETS PACK OF 4 SWALLOWS                   2
# LUNCH BAG RED RETROSPOT                      2
# RETROSPOT PARTY BAG + STICKER SET            1
# SET/4 SKULL BADGES                           1

# %% [markdown]
# Видим ручные правки, образцы, оплата доставки от амазона, почтовые расходы, банковские сборы и какие-то долги.

# %%
df[df['Description']=='Manual'].describe(include='all')
# Out:
# <ipython-input-14-a63fec0913c0>:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   df[df['Description']=='Manual'].describe(include='all')
#        InvoiceNo StockCode Description     Quantity          InvoiceDate  \
# count        567       567         567   567.000000                  567
# unique       518         2           1          NaN                  514
# top      C548830         M      Manual          NaN  2011-04-04 13:03:00
# freq           4       566         567          NaN                    4
# first        NaN       NaN         NaN          NaN  2010-12-01 15:35:00
# last         NaN       NaN         NaN          NaN  2011-12-09 10:28:00
# mean         NaN       NaN         NaN     5.158730                  NaN
# std          NaN       NaN         NaN   120.732275                  NaN
# min          NaN       NaN         NaN -1350.000000                  NaN
# 25%          NaN       NaN         NaN    -1.000000                  NaN
# 50%          NaN       NaN         NaN     1.000000                  NaN
# 75%          NaN       NaN         NaN     1.000000                  NaN
# max          NaN       NaN         NaN  1600.000000                  NaN
#
#            UnitPrice    CustomerID         Country  invoce_day     total_amt
# count     567.000000    460.000000             567         567    567.000000
# unique           NaN           NaN              17         217           NaN
# top              NaN           NaN  United Kingdom  2011-07-18           NaN
# freq             NaN           NaN             474          17           NaN
# first            NaN           NaN             NaN         NaN           NaN
# last             NaN           NaN             NaN         NaN           NaN
# mean      378.207160  15282.450000             NaN         NaN   -121.748924
# std      1779.373802   1882.606399             NaN         NaN   1841.235679
# min         0.000000  12352.000000             NaN         NaN -38970.000000
# 25%         1.000000  13263.000000             NaN         NaN    -75.330000
# 50%         8.000000  15502.000000             NaN         NaN      1.000000
# 75%       280.050000  16961.250000             NaN         NaN      8.495000
# max     38970.000000  18283.000000             NaN         NaN   4287.630000

# %% [markdown]
# StockCode всего 2 уникальных значения, посмотрим какие:

# %%
df[df['Description']=='Manual']['StockCode'].unique()
# Out:
# array(['M', 'm'], dtype=object)

# %% [markdown]
# Литеры "М" в различных видах написания.
#
# Сделаем предположение, что данные записи - какие-то ручные корректировки, которые стоит учесть в общей сумме, когда будет рассчитываться общий доход по странам и клиентам. Но если бы была такая возможность, лучше уточнить, что конкретно означают эти записи.
#
# Изучим образцы:

# %%
df[df['Description']=='SAMPLES'].describe(include='all')
# Out:
# <ipython-input-16-4e72ed05e1e7>:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   df[df['Description']=='SAMPLES'].describe(include='all')
#        InvoiceNo StockCode Description   Quantity          InvoiceDate  \
# count         62        62          62  62.000000                   62
# unique        19         1           1        NaN                   19
# top      C544580         S     SAMPLES        NaN  2011-02-21 14:25:00
# freq          15        62          62        NaN                   15
# first        NaN       NaN         NaN        NaN  2010-12-07 12:03:00
# last         NaN       NaN         NaN        NaN  2011-11-18 14:16:00
# mean         NaN       NaN         NaN  -0.935484                  NaN
# std          NaN       NaN         NaN   0.356254                  NaN
# min          NaN       NaN         NaN  -1.000000                  NaN
# 25%          NaN       NaN         NaN  -1.000000                  NaN
# 50%          NaN       NaN         NaN  -1.000000                  NaN
# 75%          NaN       NaN         NaN  -1.000000                  NaN
# max          NaN       NaN         NaN   1.000000                  NaN
#
#          UnitPrice  CustomerID         Country  invoce_day   total_amt
# count    62.000000         0.0              62          62   62.000000
# unique         NaN         NaN               1          13         NaN
# top            NaN         NaN  United Kingdom  2011-02-21         NaN
# freq           NaN         NaN              62          26         NaN
# first          NaN         NaN             NaN         NaN         NaN
# last           NaN         NaN             NaN         NaN         NaN
# mean     51.060484         NaN             NaN         NaN  -49.026613
# std      86.198654         NaN             NaN         NaN   87.390557
# min       2.800000         NaN             NaN         NaN -570.000000
# 25%       7.952500         NaN             NaN         NaN  -63.137500
# 50%      20.025000         NaN             NaN         NaN  -16.250000
# 75%      63.137500         NaN             NaN         NaN   -6.775000
# max     570.000000         NaN             NaN         NaN   33.050000

# %% [markdown]
# Образцы почти все входят в разряд убытков, кроме 2 записей. Скорее всего, это какие-то единичные платные образцы, в большинстве случаев их поставляют в убыток, можно их оставить.

# %%
display(df[df['Description']=='AMAZON FEE'].describe(include='all'))
df[df['Description']=='AMAZON FEE']
# Out:
# <ipython-input-17-291999ef16c2>:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   display(df[df['Description']=='AMAZON FEE'].describe(include='all'))
#        InvoiceNo  StockCode Description   Quantity          InvoiceDate  \
# count         34         34          34  34.000000                   34
# unique        34          1           1        NaN                   34
# top      C537651  AMAZONFEE  AMAZON FEE        NaN  2011-08-02 12:27:00
# freq           1         34          34        NaN                    1
# first        NaN        NaN         NaN        NaN  2010-12-07 12:41:00
# last         NaN        NaN         NaN        NaN  2011-12-05 11:36:00
# mean         NaN        NaN         NaN  -0.882353                  NaN
# std          NaN        NaN         NaN   0.477665                  NaN
# min          NaN        NaN         NaN  -1.000000                  NaN
# 25%          NaN        NaN         NaN  -1.000000                  NaN
# 50%          NaN        NaN         NaN  -1.000000                  NaN
# 75%          NaN        NaN         NaN  -1.000000                  NaN
# max          NaN        NaN         NaN   1.000000                  NaN
#
#            UnitPrice  CustomerID         Country  invoce_day     total_amt
# count      34.000000         0.0              34          34     34.000000
# unique           NaN         NaN               1          15           NaN
# top              NaN         NaN  United Kingdom  2010-12-07           NaN
# freq             NaN         NaN              34           7           NaN
# first            NaN         NaN             NaN         NaN           NaN
# last             NaN         NaN             NaN         NaN           NaN
# mean     7324.784706         NaN             NaN         NaN  -6515.308824
# std      4619.549649         NaN             NaN         NaN   5734.365915
# min         1.000000         NaN             NaN         NaN -17836.460000
# 25%      5233.465000         NaN             NaN         NaN  -7322.685000
# 50%      5909.875000         NaN             NaN         NaN  -5876.790000
# 75%      8071.657500         NaN             NaN         NaN  -4737.987500
# max     17836.460000         NaN             NaN         NaN  13541.330000
#        InvoiceNo  StockCode Description  Quantity         InvoiceDate  \
# 14514    C537600  AMAZONFEE  AMAZON FEE        -1 2010-12-07 12:41:00
# 15016    C537630  AMAZONFEE  AMAZON FEE        -1 2010-12-07 15:04:00
# 15017     537632  AMAZONFEE  AMAZON FEE         1 2010-12-07 15:08:00
# 16232    C537644  AMAZONFEE  AMAZON FEE        -1 2010-12-07 15:34:00
# 16313    C537647  AMAZONFEE  AMAZON FEE        -1 2010-12-07 15:41:00
# 16356    C537651  AMAZONFEE  AMAZON FEE        -1 2010-12-07 15:49:00
# 16357    C537652  AMAZONFEE  AMAZON FEE        -1 2010-12-07 15:51:00
# 43702    C540117  AMAZONFEE  AMAZON FEE        -1 2011-01-05 09:55:00
# 43703    C540118  AMAZONFEE  AMAZON FEE        -1 2011-01-05 09:57:00
# 96844    C544587  AMAZONFEE  AMAZON FEE        -1 2011-02-21 15:07:00
# 96845    C544589  AMAZONFEE  AMAZON FEE        -1 2011-02-21 15:11:00
# 124741   C546987  AMAZONFEE  AMAZON FEE        -1 2011-03-18 12:56:00
# 124787   C546989  AMAZONFEE  AMAZON FEE        -1 2011-03-18 12:59:00
# 135534    547901  AMAZONFEE  AMAZON FEE         1 2011-03-28 11:57:00
# 135590   C547904  AMAZONFEE  AMAZON FEE        -1 2011-03-28 12:02:00
# 191385   C553354  AMAZONFEE  AMAZON FEE        -1 2011-05-16 13:54:00
# 191386   C553355  AMAZONFEE  AMAZON FEE        -1 2011-05-16 13:58:00
# 239250   C558036  AMAZONFEE  AMAZON FEE        -1 2011-06-24 12:31:00
# 239251   C558037  AMAZONFEE  AMAZON FEE        -1 2011-06-24 12:33:00
# 262413   C559915  AMAZONFEE  AMAZON FEE        -1 2011-07-13 15:18:00
# 262414   C559917  AMAZONFEE  AMAZON FEE        -1 2011-07-13 15:21:00
# 287103   C562062  AMAZONFEE  AMAZON FEE        -1 2011-08-02 12:17:00
# 287150   C562086  AMAZONFEE  AMAZON FEE        -1 2011-08-02 12:27:00
# 312092   C564340  AMAZONFEE  AMAZON FEE        -1 2011-08-24 14:50:00
# 312246   C564341  AMAZONFEE  AMAZON FEE        -1 2011-08-24 14:53:00
# 342611   C566889  AMAZONFEE  AMAZON FEE        -1 2011-09-15 13:50:00
# 342635   C566899  AMAZONFEE  AMAZON FEE        -1 2011-09-15 13:53:00
# 383495   C570025  AMAZONFEE  AMAZON FEE        -1 2011-10-07 10:29:00
# 429248   C573549  AMAZONFEE  AMAZON FEE        -1 2011-10-31 13:23:00
# 429249   C573550  AMAZONFEE  AMAZON FEE        -1 2011-10-31 13:32:00
# 446434   C574897  AMAZONFEE  AMAZON FEE        -1 2011-11-07 15:03:00
# 446533   C574902  AMAZONFEE  AMAZON FEE        -1 2011-11-07 15:21:00
# 524601   C580604  AMAZONFEE  AMAZON FEE        -1 2011-12-05 11:35:00
# 524602   C580605  AMAZONFEE  AMAZON FEE        -1 2011-12-05 11:36:00
#
#         UnitPrice  CustomerID         Country  invoce_day  total_amt
# 14514        1.00         NaN  United Kingdom  2010-12-07      -1.00
# 15016    13541.33         NaN  United Kingdom  2010-12-07  -13541.33
# 15017    13541.33         NaN  United Kingdom  2010-12-07   13541.33
# 16232    13474.79         NaN  United Kingdom  2010-12-07  -13474.79
# 16313     5519.25         NaN  United Kingdom  2010-12-07   -5519.25
# 16356    13541.33         NaN  United Kingdom  2010-12-07  -13541.33
# 16357     6706.71         NaN  United Kingdom  2010-12-07   -6706.71
# 43702    16888.02         NaN  United Kingdom  2011-01-05  -16888.02
# 43703    16453.71         NaN  United Kingdom  2011-01-05  -16453.71
# 96844     5575.28         NaN  United Kingdom  2011-02-21   -5575.28
# 96845     5258.77         NaN  United Kingdom  2011-02-21   -5258.77
# 124741    5693.05         NaN  United Kingdom  2011-03-18   -5693.05
# 124787    5225.03         NaN  United Kingdom  2011-03-18   -5225.03
# 135534     219.76         NaN  United Kingdom  2011-03-28     219.76
# 135590     219.76         NaN  United Kingdom  2011-03-28    -219.76
# 191385    5876.40         NaN  United Kingdom  2011-05-16   -5876.40
# 191386    7006.83         NaN  United Kingdom  2011-05-16   -7006.83
# 239250    5791.18         NaN  United Kingdom  2011-06-24   -5791.18
# 239251    4534.24         NaN  United Kingdom  2011-06-24   -4534.24
# 262413    4383.62         NaN  United Kingdom  2011-07-13   -4383.62
# 262414    6497.47         NaN  United Kingdom  2011-07-13   -6497.47
# 287103    4575.64         NaN  United Kingdom  2011-08-02   -4575.64
# 287150    6721.37         NaN  United Kingdom  2011-08-02   -6721.37
# 312092    4527.65         NaN  United Kingdom  2011-08-24   -4527.65
# 312246    6662.51         NaN  United Kingdom  2011-08-24   -6662.51
# 342611    5522.14         NaN  United Kingdom  2011-09-15   -5522.14
# 342635    7427.97         NaN  United Kingdom  2011-09-15   -7427.97
# 383495    5942.57         NaN  United Kingdom  2011-10-07   -5942.57
# 429248    5942.57         NaN  United Kingdom  2011-10-31   -5942.57
# 429249    2185.04         NaN  United Kingdom  2011-10-31   -2185.04
# 446434    5877.18         NaN  United Kingdom  2011-11-07   -5877.18
# 446533    8286.22         NaN  United Kingdom  2011-11-07   -8286.22
# 524601   11586.50         NaN  United Kingdom  2011-12-05  -11586.50
# 524602   17836.46         NaN  United Kingdom  2011-12-05  -17836.46

# %% [markdown]
# Оставляем этот раздел.

# %%
df[(df['Description']=='CHRISTMAS TREE HANGING GOLD')&(df['CustomerID'].isna())]
# Out:
#        InvoiceNo StockCode                  Description  Quantity  \
# 393624    570837     23222  CHRISTMAS TREE HANGING GOLD        12
# 397665   C571196     23222  CHRISTMAS TREE HANGING GOLD       -12
# 430983    573585     23222  CHRISTMAS TREE HANGING GOLD         1
# 437680    574298     23222  CHRISTMAS TREE HANGING GOLD         1
# 450977    575177     23222  CHRISTMAS TREE HANGING GOLD         1
# 457512    575739     23222  CHRISTMAS TREE HANGING GOLD         1
# 459582    575875     23222  CHRISTMAS TREE HANGING GOLD         2
# 477961    577078     23222  CHRISTMAS TREE HANGING GOLD         1
# 496352    578344     23222  CHRISTMAS TREE HANGING GOLD         1
# 507773    579187     23222  CHRISTMAS TREE HANGING GOLD         1
# 515040    579777     23222  CHRISTMAS TREE HANGING GOLD         1
# 518498    580115     23222  CHRISTMAS TREE HANGING GOLD         1
#
#                InvoiceDate  UnitPrice  CustomerID         Country  invoce_day  \
# 393624 2011-10-12 13:55:00       0.83         NaN  United Kingdom  2011-10-12
# 397665 2011-10-14 12:02:00       0.83         NaN  United Kingdom  2011-10-14
# 430983 2011-10-31 14:41:00       1.63         NaN  United Kingdom  2011-10-31
# 437680 2011-11-03 15:56:00       1.63         NaN  United Kingdom  2011-11-03
# 450977 2011-11-08 18:41:00       1.63         NaN  United Kingdom  2011-11-08
# 457512 2011-11-11 09:05:00       1.63         NaN  United Kingdom  2011-11-11
# 459582 2011-11-11 13:06:00       1.63         NaN  United Kingdom  2011-11-11
# 477961 2011-11-17 15:17:00       1.63         NaN  United Kingdom  2011-11-17
# 496352 2011-11-24 09:21:00       1.63         NaN  United Kingdom  2011-11-24
# 507773 2011-11-28 15:31:00       1.63         NaN  United Kingdom  2011-11-28
# 515040 2011-11-30 15:13:00       1.63         NaN  United Kingdom  2011-11-30
# 518498 2011-12-01 16:22:00       1.63         NaN  United Kingdom  2011-12-01
#
#         total_amt
# 393624       9.96
# 397665      -9.96
# 430983       1.63
# 437680       1.63
# 450977       1.63
# 457512       1.63
# 459582       3.26
# 477961       1.63
# 496352       1.63
# 507773       1.63
# 515040       1.63
# 518498       1.63

# %% [markdown]
# По итогу я бы не стала удалять записи с отрицательными суммами, так как они отражают реальную картину:
# - это отмены товаров;
# - ручные корректировки (предположительно);
# - оплата доставки Амазон;
# - банковские сборы;
# - бесплатные образцы.
#
# Теперь проведем классификацию товаров с помощью машинного обучения.

# %%
from pymystem3 import Mystem

# %%
abc = 'One two and another numbers. I am counting right now.'
m = Mystem()

lemmas = m.lemmatize(abc)

# %%
lemmas
# Out:
# ['One',
#  ' ',
#  'two',
#  ' ',
#  'and',
#  ' ',
#  'another',
#  ' ',
#  'numbers',
#  '. ',
#  'I',
#  ' ',
#  'am',
#  ' ',
#  'counting',
#  ' ',
#  'right',
#  ' ',
#  'now',
#  '.',
#  '\n']

# %%
from collections import Counter

# %%
Counter(lemmas)
# Out:
# Counter({'One': 1,
#          ' ': 8,
#          'two': 1,
#          'and': 1,
#          'another': 1,
#          'numbers': 1,
#          '. ': 1,
#          'I': 1,
#          'am': 1,
#          'counting': 1,
#          'right': 1,
#          'now': 1,
#          '.': 1,
#          '\n': 1})

# %%
import nltk
nltk.download('wordnet')
from nltk.stem import WordNetLemmatizer 

# Init the Wordnet Lemmatizer
lemmatizer = WordNetLemmatizer()
# Lemmatize Single Word
print(lemmatizer.lemmatize("bats"))
#> bat
print(lemmatizer.lemmatize("are"))
#> are
print(lemmatizer.lemmatize("feet"))
#> foot
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/Anastasia/nltk_data...
# bat
# are
# foot

# %%
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country  invoce_day  \
# 0      2010-12-01 08:26:00       2.55     17850.0  United Kingdom  2010-12-01
# 1      2010-12-01 08:26:00       3.39     17850.0  United Kingdom  2010-12-01
# 2      2010-12-01 08:26:00       2.75     17850.0  United Kingdom  2010-12-01
# 3      2010-12-01 08:26:00       3.39     17850.0  United Kingdom  2010-12-01
# 4      2010-12-01 08:26:00       3.39     17850.0  United Kingdom  2010-12-01
# ...                    ...        ...         ...             ...         ...
# 541904 2011-12-09 12:50:00       0.85     12680.0          France  2011-12-09
# 541905 2011-12-09 12:50:00       2.10     12680.0          France  2011-12-09
# 541906 2011-12-09 12:50:00       4.15     12680.0          France  2011-12-09
# 541907 2011-12-09 12:50:00       4.15     12680.0          France  2011-12-09
# 541908 2011-12-09 12:50:00       4.95     12680.0          France  2011-12-09
#
#         total_amt
# 0           15.30
# 1           20.34
# 2           22.00
# 3           20.34
# 4           20.34
# ...           ...
# 541904      10.20
# 541905      12.60
# 541906      16.60
# 541907      16.60
# 541908      14.85
#
# [536641 rows x 10 columns]

# %%
df['lemma'] = df['Description'].apply(
                                lambda x: ' '.join(
                                [lemmatizer.lemmatize(i.lower()) for i in re.findall(r'(?i)([a-zA-Z]+)', str(x))]))
df.sample(10)
# Out:
#        InvoiceNo StockCode                         Description  Quantity  \
# 150957    549525     22856  ASSORTED EASTER DECORATIONS  BELLS         1
# 522694    580432     22221     CAKE STAND LOVEBIRD 2 TIER PINK        12
# 531868    580974     21934                  SKULL SHOULDER BAG        10
# 484132    577521     22469               HEART OF WICKER SMALL         2
# 121515    546769     22844    VINTAGE CREAM DOG FOOD CONTAINER         2
# 119302    546538     20972  PINK CREAM FELT CRAFT TRINKET BOX         12
# 41143     539752     22221     CAKE STAND LOVEBIRD 2 TIER PINK         2
# 131400    547561     23127               DOLLCRAFT GIRL NICOLE         4
# 424208    573245     82482   WOODEN PICTURE FRAME WHITE FINISH         1
# 18317     537818     21844                   RED RETROSPOT MUG         6
#
#                InvoiceDate  UnitPrice  CustomerID         Country  invoce_day  \
# 150957 2011-04-08 15:44:00      15.79         NaN  United Kingdom  2011-04-08
# 522694 2011-12-04 12:14:00       2.95     13153.0  United Kingdom  2011-12-04
# 531868 2011-12-06 15:17:00       1.65     14293.0  United Kingdom  2011-12-06
# 484132 2011-11-20 13:23:00       1.65     16411.0  United Kingdom  2011-11-20
# 121515 2011-03-16 14:57:00       8.50     17504.0  United Kingdom  2011-03-16
# 119302 2011-03-14 14:51:00       1.25     16327.0  United Kingdom  2011-03-14
# 41143  2010-12-21 15:43:00       9.95     12515.0           Italy  2010-12-21
# 131400 2011-03-24 08:44:00       4.95     14129.0  United Kingdom  2011-03-24
# 424208 2011-10-28 12:08:00       2.95     17841.0  United Kingdom  2011-10-28
# 18317  2010-12-08 13:53:00       2.95     12766.0        Portugal  2010-12-08
#
#         total_amt                              lemma
# 150957      15.79    assorted easter decoration bell
# 522694      35.40      cake stand lovebird tier pink
# 531868      16.50                 skull shoulder bag
# 484132       3.30              heart of wicker small
# 121515      17.00   vintage cream dog food container
# 119302      15.00  pink cream felt craft trinket box
# 41143       19.90      cake stand lovebird tier pink
# 131400      19.80              dollcraft girl nicole
# 424208       2.95  wooden picture frame white finish
# 18317       17.70                  red retrospot mug

# %%
test = 'SET 7 BABUSHKA NESTING BOXES'
re.findall(r'(?i)([a-zA-Z]+)', test)
# Out:
# ['SET', 'BABUSHKA', 'NESTING', 'BOXES']

# %%
text = 'ул. Карпинского, дом № 20, корпус 3, квартира 98'
re.findall(r'(?i)([а-я]+)', text)
# Out:
# ['ул', 'Карпинского', 'дом', 'корпус', 'квартира']

# %%
test.split()
# Out:
# ['SET', '7', 'BABUSHKA', 'NESTING', 'BOXES']

# %%
for i in re.findall(r'(?i)([a-zA-Z]+)', test):
    print(lemmatizer.lemmatize(i.lower()))
# Out:
# set
# babushka
# nesting
# box

# %%
lemmatizer.lemmatize("BOXES")
# Out:
# 'BOXES'

# %%
re.split(r'[ ]', test)
# Out:
# ['SET', '7', 'BABUSHKA', 'NESTING', 'BOXES']

# %%
' '.join([lemmatizer.lemmatize(i.lower()) for i in re.findall(r'(?i)([a-zA-Z]+)', test)])
# Out:
# 'set babushka nesting box'

# %%
df['Description'].unique()
# Out:
# array(['WHITE HANGING HEART T-LIGHT HOLDER', 'WHITE METAL LANTERN',
#        'CREAM CUPID HEARTS COAT HANGER', ..., 'lost',
#        'CREAM HANGING HEART T-LIGHT HOLDER',
#        'PAPER CRAFT , LITTLE BIRDIE'], dtype=object)

# %%
def try_except_lambda(value, change):
    try:
        return value
    except:
        return change

# %%
for x in df['Description'].unique():
    try:
        ' '.join([lemmatizer.lemmatize(i.lower()) for i in re.findall(r'(?i)([a-zA-Z]+)', str(x))])
    except Exception as e: 
        print(e)
        print(x)

# %%
l = lambda x: ' '.join(
    [lemmatizer.lemmatize(i.lower()) for i in re.findall(r'(?i)([a-zA-Z]+)', str(x))])
